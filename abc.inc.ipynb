# %% [markdown]
# # ANALYSIS OF SALES DATA

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##Reading the csv files

# %%
d_budget = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\BUDGET.csv')
d_caddress = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\CUSTOMERADDRESS.csv')
d_customers = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\CUSTOMERS.csv')
d_division = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\DIVISION.csv')
d_itembranch = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\ITEMBRANCH.csv')
d_itemmaster = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\ITEMMASTER.csv')
d_region = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\REGION.csv')
d_salesdetails = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\SALESDETAILS.csv')
d_salesrep = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\SALESREP.csv')
d_statedescription = pd.read_csv (r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\STATEDESCRIPTION.csv')
# Out:
# C:\Users\hhh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
d_budget
# Out:
#        BudgetPeriod  Budget Amount  BudgetYear  Customer Number  \
# 0                 1     -4841.4000        2008         10015325
# 1                 1     -2927.5300        2008         10025305
# 2                 1     -1464.9500        2008         10025269
# 3                 1     -1126.7400        2008         10000455
# 4                 1      -971.6500        2008         10015783
# ...             ...            ...         ...              ...
# 13999            12    486697.0860        2009         10025039
# 14000            12    482591.0784        2009         10002154
# 14001            12    483985.0900        2009         10006919
# 14002            12    633522.5784        2009         10007536
# 14003            12    542197.8232        2009         10019066
#
#       textBudgetPeriod
# 0                  Jan
# 1                  Jan
# 2                  Jan
# 3                  Jan
# 4                  Jan
# ...                ...
# 13999              Dec
# ...

# %%
d_caddress
# Out:
#      Address Number                       City Country  \
# 0          10025919                    Compton      US
# 1          10025249                    Memphis      US
# 2          10025249                    Memphis      US
# 3          10011732                                 UK
# 4          10011732                                 UK
# ..              ...                        ...     ...
# 684        10025808                  Bremorton      US
# 685        10020171                 Morgantown      US
# 686        10000462                  Hazelwood      US
# 687        10009697                    Orlando      US
# 688        10009697                    Orlando      US
#
#                            Customer Address 1  \
# 0                  801 West Artesia Boulevard
# 1                             7221 Highway 64
# 2                             7221 Highway 64
# 3
# 4
# ..                                        ...
# 684                          3519 Arsonal Way
# ...

# %%
d_customers
# Out:
#      Address Number Business Family  Business Unit            Customer  \
# 0          10025778              R3              1   Valicert Midstore
# 1          10021222              R3              1          Pacifico's
# 2          10020663              R3              1      Neos Gigaplace
# 3          10022456              R3              1        Ra Maxistore
# 4          10025919              R3              1            Vanstars
# ..              ...             ...            ...                 ...
# 679        10023511              R1              1    Sage Supermarket
# 680        10024919              R1              1  T.J.T. Supermarket
# 681        10011286              R4              1      Emergency Shop
# 682        10025359              R4              1    UKnames.net Shop
# 683        10006983              O1              1     Brentano's Shop
#
#      Customer Number Customer Type  Division Line of Business         Phone  \
# ...

# %%
d_division.head(5)
# Out:
#    Division Name  Division
# 0  International         1
# 1       Domestic         2

# %%
d_itembranch
# Out:
#      Item Branch 2nd Item Number  Item Branch Category Code 6  \
# 0                          30147                         1030
# 1                          30147                         1030
# 2                          27569                         1015
# 3                          27569                         1015
# 4                          34783                         1035
# ...                          ...                          ...
# 5127                       30146                         1030
# 5128                       39235                         1035
# 5129                       25257                         1045
# 5130                       38814                         1010
# 5131                      915411                         5020
#
#      Item Branch G/L Category Item-Branch Key  Item Branch Reorder Quantity  \
# 0                        TMTG        CR-10977                             0
# ...

# %%
d_itemmaster.head(5)
# Out:
#   Master Planning Family Product Department  Product Group  Product Line  \
# 0                                                        7             1
# 1                                                        7             1
# 2                                                        7             1
# 3                    G09                  1              7             1
# 4                    G09                  1              7             1
#
#   Product Price Group  Product Sub Group  Product Type  Short Name
# 0                   N                  3            26       10977
# 1                   N                  3            26       10977
# 2                   N                  3            26       10977
# 3                                      3            26       10977
# 4                                      3            26       10977

# %%
d_region.head(5)
# Out:
#      Region Name  Region Code
# 0  International            5
# 1         Canada            0
# 2        Western            1
# 3       Southern            2
# 4      Northeast            3

# %%
d_salesdetails
# Out:
#         Actual Delivery Date  Address Number   CustKey  Backlog Amount  \
# 0                        NaN        10025919  10025919             NaN
# 1                        NaN        10025919  10025919             NaN
# 2                        NaN        10025919  10025919             NaN
# 3                        NaN        10025919  10025919             NaN
# 4                        NaN        10025919  10025919             NaN
# ...                      ...             ...       ...             ...
# 296136               40162.0        10011360  10011360             NaN
# 296137               39970.0        10015325  10015325             NaN
# 296138               39933.0        10026268  10026268             NaN
# 296139               39932.0        10021203  10021203             NaN
# 296140               39970.0        10015325  10015325             NaN
#
#         BackOrder Amount     DateKey  Discount Amount Doc Type Family Class  \
# ...

# %%
d_salesrep.head()
# Out:
#    Sales Rep Sales Rep Name
# 0        108    Brad Taylor
# 1        162    Peggie Hurt
# 2        136     Jose Bowen
# 3        139   Judy Rowlett
# 4        141   Judy Thurman

# %%
d_statedescription.head(5)
# Out:
#   State state_abbr  state_name
# 0    AK         AK      Alaska
# 1    AL         AL     Alabama
# 2    AR         AR    Arkansas
# 3    AZ         AZ     Arizona
# 4    CA         CA  California

# %% [markdown]
# ##Reading the text files

# %%
d_productline = pd.read_csv(r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\PRODUCTLINE.txt', delimiter = "\t")
d_productgroup = pd.read_csv(r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\PRODUCTGROUP.txt', delimiter = "\t")
d_productsubgroup = pd.read_csv(r'C:\Users\hhh\Desktop\Data Fiesta 2.0 Round 2 Docket\Data Fiesta 2.0 Round 2 -  Data\PRODUCTSUBGROUP.txt', delimiter = "\t")

# %% [markdown]
# ##Missing valus

# %%
fig, axes= plt.subplots(figsize=(20, 12), ncols=5,nrows=2)
sns.heatmap(d_budget.isnull(),cbar=False,ax=axes[0][0])
axes[0][0].set_title("Budget")
sns.heatmap(d_caddress.isnull(),cbar=False,ax=axes[0][1])
axes[0][1].set_title("Customer Address")
sns.heatmap(d_customers.isnull(),cbar=False,ax=axes[0][2])
axes[0][2].set_title("Customers")
sns.heatmap(d_division.isnull(),cbar=False,ax=axes[0][3])
axes[0][3].set_title("Division")
sns.heatmap(d_itembranch.isnull(),cbar=False,ax=axes[1][0])
axes[1][0].set_title("Item Branch")
sns.heatmap(d_itemmaster.isnull(),cbar=False,ax=axes[1][1])
axes[1][1].set_title("Item Master")
sns.heatmap(d_region.isnull(),cbar=False,ax=axes[1][2])
axes[1][2].set_title("Region")
sns.heatmap(d_salesdetails.isnull(),cbar=False,ax=axes[1][3])
axes[1][3].set_title("Sales Details")
sns.heatmap(d_salesrep.isnull(),cbar=False,ax=axes[0][4])
axes[0][4].set_title("Sales Rep")
sns.heatmap(d_statedescription.isnull(),cbar=False,ax=axes[1][4])
axes[1][4].set_title("State Description")
plt.tight_layout()

# %% [markdown]
# ##We can conclude from the Heatmap that some datasets have null values in it.
# ##So it is required to Clean Dataset(remove null values) before operating on column which has null values

# %% [markdown]
# # Insight 1

# %%
ad=pd.merge(d_customers,d_region, on ='Region Code')
ad=pd.merge(ad,d_division, on ='Division')
ad=pd.merge(ad,d_caddress, on ='Address Number')
ad=pd.merge(ad,d_statedescription, on ='State')
ad.head()
# Out:
#    Address Number Business Family  Business Unit               Customer  \
# 0        10025778              R3              1      Valicert Midstore
# 1        10022456              R3              1           Ra Maxistore
# 2        10025919              R3              1               Vanstars
# 3        10024270              R3              1  Signatures Superstore
# 4        10024270              R3              1  Signatures Superstore
#
#    Customer Number Customer Type  Division Line of Business         Phone  \
# 0         10025778            G2         2                   816-455-8733
# 1         10022456            G2         2                   816-455-8733
# 2         10025919            G2         2               M1  816-455-8733
# 3         10024270            G2         2                   816-455-8733
# 4         10024270            G2         2                   816-455-8733
#
#    Region Code  ...            City Country          Customer Address 1  \
# ...

# %%
fig, axes= plt.subplots(figsize=(8,5))
total = float(len(ad))
ax=sns.countplot(x='Division Name',linewidth=15,data=ad)
axes.set_title("Disribution of Customers ")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()
plt.tight_layout()

# %% [markdown]
# ##From above countplot we can say that 92.9% customers are domestic

# %%
fig, axes= plt.subplots(figsize=(40,20))
total = float(len(ad))
ax=sns.countplot(x='state_name',linewidth=15,data=ad)
axes.set_title("Disribution of Customers in Domestic Division ")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.tight_layout()

# %% [markdown]
# ##From the plot we can see that 10.1% of the domestic customers are from California

# %%
p=ad[ad['State'].str.contains('CA')]
fig, axes= plt.subplots(figsize=(25, 6))
total = float(len(p))
ax=sns.countplot(x='City',linewidth=15,data=p)
axes.set_title("Disribution of Customers in California ")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.tight_layout()

# %% [markdown]
# ##Scaramento is the city with most number of customers in California with 22.8% customers of california in it.

# %% [markdown]
# # Insight 4

# %%
add=pd.merge(d_salesrep,d_salesdetails, on ='Sales Rep')

# %%
add.head(5)
# Out:
#    Sales Rep Sales Rep Name  Actual Delivery Date  Address Number   CustKey  \
# 0        108    Brad Taylor                   NaN        10025919  10025919
# 1        108    Brad Taylor                   NaN        10025919  10025919
# 2        108    Brad Taylor                   NaN        10025919  10025919
# 3        108    Brad Taylor                   NaN        10025919  10025919
# 4        108    Brad Taylor                   NaN        10025919  10025919
#
#    Backlog Amount  BackOrder Amount    DateKey  Discount Amount Doc Type  ...  \
# 0             NaN               NaN  7/21/2008              NaN           ...
# 1             NaN               NaN  6/27/2008              NaN           ...
# 2             NaN               NaN   5/8/2008              NaN           ...
# 3             NaN               NaN   5/8/2008              NaN           ...
# 4             NaN               NaN  6/27/2008              NaN           ...
#
# ...

# %%
fig, axes= plt.subplots(figsize=(8,12))
sns.countplot(y='Sales Rep Name',linewidth=15,data=add)
axes.set_title("Sales Representative with maximum number of Sales ")
plt.tight_layout()

# %% [markdown]
# ##The Name of the Sales Rep with maximum number of sales is Brad Taylor

# %% [markdown]
# # Insight 8

# %%
add=pd.merge(d_budget,d_customers, on ='Customer Number')
add
# Out:
#        BudgetPeriod  Budget Amount  BudgetYear  Customer Number  \
# 0                 1        -4841.4        2008         10015325
# 1                 1            0.0        2008         10015325
# 2                 2         5042.5        2008         10015325
# 3                 2            0.0        2008         10015325
# 4                 3            0.0        2008         10015325
# ...             ...            ...         ...              ...
# 14027            12            0.0        2008         10005620
# 14028            10            0.0        2009         10005620
# 14029            12            0.0        2009         10005620
# 14030            10            0.0        2008         10026536
# 14031            10            0.0        2009         10026536
#
#       textBudgetPeriod  Address Number Business Family  Business Unit  \
# 0                  Jan        10015325              R2              1
# ...

# %%
p = add.loc[add.groupby('Customer')['Budget Amount'].idxmax()].sort_values(by='Budget Amount', ascending=False).head(10)
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(x='Budget Amount', y= 'Customer', data=p, palette='coolwarm', axes=ax)
ax.set_title("Bars showing Customer with highest budget")
plt.tight_layout()

# %%
q=p[['Customer Number','Customer','Budget Amount','textBudgetPeriod']].dropna().reset_index()
q
# Out:
#    index  Customer Number            Customer  Budget Amount textBudgetPeriod
# 0   8025         10025039    Tandy Superstore   1.754965e+06              Aug
# 1   7425         10021485   Paracel Gigaplace   1.671976e+06              Feb
# 2   7447         10025024           Talarians   1.408633e+06              Feb
# 3   8418         10002154     Acer Superstore   1.209787e+06              Aug
# 4   9067         10006919   Hoovey SuperStore   9.617922e+05              Jul
# 5   7102         10025919            Vanstars   9.335121e+05              Apr
# 6   3398         10025552    Unison Medistore   7.032541e+05              Jul
# 7   6294         10021204       Pacific Store   6.561572e+05              Jun
# 8   9887         10007536  Calypso Maxi Store   6.335226e+05              Dec
# 9   5052         10017638    Kellys Gigastore   6.002452e+05              Sep

# %%
q.to_csv('ex123')

# %% [markdown]
# ##Customers with highest budeget is Tandy Superstore

# %% [markdown]
# # Insight 10

# %%
add=pd.merge(d_caddress,d_salesdetails, on ='Address Number')
add
# Out:
#         Address Number     City Country          Customer Address 1  \
# 0             10025919  Compton      US  801 West Artesia Boulevard
# 1             10025919  Compton      US  801 West Artesia Boulevard
# 2             10025919  Compton      US  801 West Artesia Boulevard
# 3             10025919  Compton      US  801 West Artesia Boulevard
# 4             10025919  Compton      US  801 West Artesia Boulevard
# ...                ...      ...     ...                         ...
# 375093        10009697  Orlando      US       4455 Dardanelle Drive
# 375094        10009697  Orlando      US       4455 Dardanelle Drive
# 375095        10009697  Orlando      US       4455 Dardanelle Drive
# 375096        10009697  Orlando      US       4455 Dardanelle Drive
# 375097        10009697  Orlando      US       4455 Dardanelle Drive
#
#                               Customer Address 2  \
# 0
# 1
# 2
# 3
# 4
# ...                                          ...
# 375093
# 375094
# 375095
# ...

# %%
fig, axes= plt.subplots(figsize=(6, 4))
total = float(len(add))
ax=sns.countplot(x='U/M',linewidth=15,data=add)
ax.set_title("Count of The Unit of measuer used for quantity")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.tight_layout()

# %% [markdown]
# ##EA(abbreviation for each) is the most used about 92.5%.

# %% [markdown]
# # Insight 5

# %%
add=pd.merge(d_caddress,d_salesdetails, on ='Address Number')
p= add[add['Sales Price'].notna()]

p
# Out:
#         Address Number     City Country          Customer Address 1  \
# 425           10025919  Compton      US  801 West Artesia Boulevard
# 426           10025919  Compton      US  801 West Artesia Boulevard
# 427           10025919  Compton      US  801 West Artesia Boulevard
# 428           10025919  Compton      US  801 West Artesia Boulevard
# 429           10025919  Compton      US  801 West Artesia Boulevard
# ...                ...      ...     ...                         ...
# 375093        10009697  Orlando      US       4455 Dardanelle Drive
# 375094        10009697  Orlando      US       4455 Dardanelle Drive
# 375095        10009697  Orlando      US       4455 Dardanelle Drive
# 375096        10009697  Orlando      US       4455 Dardanelle Drive
# 375097        10009697  Orlando      US       4455 Dardanelle Drive
#
#                               Customer Address 2  \
# 425
# 426
# 427
# 428
# 429
# ...                                          ...
# 375093
# 375094
# ...

# %%
p=p[['Sales Price','Sales Unit Cost Price']].reset_index()
p
# Out:
#          index  Sales Price  Sales Unit Cost Price
# 0          425      544.710               470.0859
# 1          426       71.180                55.9498
# 2          427        0.000                 0.0000
# 3          428        0.000                 0.0000
# 4          429        0.000               145.5700
# ...        ...          ...                    ...
# 360540  375093      101.000                29.1229
# 360541  375094       57.910                22.6737
# 360542  375095       57.910                22.6737
# 360543  375096       10.128                 4.9718
# 360544  375097       10.128                 4.9718
#
# [360545 rows x 3 columns]

# %%
sell=p['Sales Price'].sum()
sell
# Out:
# 42193733.21113271

# %%
cost=p['Sales Unit Cost Price'].sum()
cost
# Out:
# 24143718.5921

# %%
profit=(sell-cost)/cost
profit
# Out:
# 0.747607066002617

# %%
profit_percent=profit*100
profit_percent
# Out:
# 74.7607066002617

# %%
prof=['profit based on sales price and sales unit cost price','  ']
data=['74.7607066002617','25.2392933997383']
plt.pie(data, labels = prof,autopct='%1.0f%%')
plt.show()

# %% [markdown]
# # Insight 7

# %%
add=pd.merge(d_itemmaster,d_productsubgroup, on ='Product Sub Group')
add
# Out:
#      Master Planning Family Product Department  Product Group  Product Line  \
# 0                                                           7             1
# 1                                                           7             1
# 2                                                           7             1
# 3                       G09                  1              7             1
# 4                       G09                  1              7             1
# ...                     ...                ...            ...           ...
# 7474                                         0             20             1
# 7475                                         0             20             1
# 7476                      0                                20             1
# 7477                      0                                20             1
# 7478                      0                                20             1
#
# ...

# %%
add1=pd.merge(d_itemmaster,d_productgroup, on ='Product Group')
add1
# Out:
#      Master Planning Family Product Department  Product Group  Product Line  \
# 0                                                           7             1
# 1                                                           7             1
# 2                                                           7             1
# 3                       G09                  1              7             1
# 4                       G09                  1              7             1
# ...                     ...                ...            ...           ...
# 7474                                         0             20             1
# 7475                                         0             20             1
# 7476                      0                                20             1
# 7477                      0                                20             1
# 7478                      0                                20             1
#
# ...

# %%
fig, axes= plt.subplots(figsize=(15,18),nrows=2)
sns.countplot(y='Product Group Desc',data=add1,ax=axes[0])
axes[0].set_title("Product Group")
sns.countplot(y='Product Sub Group Desc',data=add,ax=axes[1])
axes[1].set_title("Product Subgroup")
plt.tight_layout()

# %% [markdown]
# ##Maximum number of products belong to Product Group 'Produce' an Subgroub 'Fresh Vegetables'

# %% [markdown]
# # Insight 6

# %%
add=pd.merge(d_itemmaster,d_productline, on ='Product Line')
add
# Out:
#      Master Planning Family Product Department  Product Group  Product Line  \
# 0                                                           7             1
# 1                                                           7             1
# 2                                                           7             1
# 3                       G09                  1              7             1
# 4                       G09                  1              7             1
# ...                     ...                ...            ...           ...
# 7474                     50                  1              4             2
# 7475                     50                  1              4             2
# 7476                                         N              4             2
# 7477                                         N              4             2
# 7478                                         N              4             2
#
# ...

# %%
fig, axes= plt.subplots(figsize=(10,5))
total = float(len(add))
ax=sns.countplot(x='Product Line Desc',data=add)
axes.set_title("More Used Product Line ")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.tight_layout()

# %% [markdown]
#  ##Maximum Product belong to Product line 'Food' that is 87.6%

# %% [markdown]
# # Insight 9

# %%
add=pd.merge(d_itembranch,d_salesdetails, on ='Item-Branch Key')
add
# Out:
#         Item Branch 2nd Item Number  Item Branch Category Code 6  \
# 0                             30147                         1030
# 1                             30147                         1030
# 2                             30147                         1030
# 3                             30147                         1030
# 4                             30147                         1030
# ...                             ...                          ...
# 1785553                       29973                         1065
# 1785554                       29973                         1065
# 1785555                       29973                         1065
# 1785556                       29973                         1065
# 1785557                       29973                         1065
#
#         Item Branch G/L Category Item-Branch Key  \
# 0                           TMTG        CR-10977
# 1                           TMTG        CR-10977
# ...

# %%
fig, axes= plt.subplots(figsize=(15,12),nrows=2)
total = float(len(add))
ax=sns.countplot(x='Item Branch Category Code 6',data=add,ax=axes[0])
axes[0].set_title("Item Branch Category Code 6")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
ax=sns.countplot(x='Item Branch G/L Category',data=add,ax=axes[1])
axes[1].set_title("Item Branch G/L Category")
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.tight_layout()

# %% [markdown]
# ##Item Branch G/L Category with maximum no. of sales=SRCW ,26.3% of total

# %% [markdown]
# ##Item Branch Category Code 6 with maximum no. sales=1015,26.3% of total

# %% [markdown]
# # Insight 2

# %%
add=pd.merge(d_caddress,d_salesdetails, on ='Address Number')
add=pd.merge(add,d_statedescription, on ='State')
p= add[add['Sales Price'].notna()]
p
# Out:
#         Address Number        City Country          Customer Address 1  \
# 425           10025919     Compton      US  801 West Artesia Boulevard
# 426           10025919     Compton      US  801 West Artesia Boulevard
# 427           10025919     Compton      US  801 West Artesia Boulevard
# 428           10025919     Compton      US  801 West Artesia Boulevard
# 429           10025919     Compton      US  801 West Artesia Boulevard
# ...                ...         ...     ...                         ...
# 304289        10020171  Morgantown      US           1537 Sabraton Ave
# 304290        10020171  Morgantown      US           1537 Sabraton Ave
# 304291        10020171  Morgantown      US           1537 Sabraton Ave
# 304292        10020171  Morgantown      US           1537 Sabraton Ave
# 304293        10020171  Morgantown      US           1537 Sabraton Ave
#
#                               Customer Address 2  \
# 425
# 426
# 427
# 428
# 429
# ...

# %%
q = p.loc[p.groupby('State')['Sales Margin Amount'].idxmax()].sort_values(by='Sales Margin Amount', ascending=False).head(10)
q
# Out:
#         Address Number               City Country       Customer Address 1  \
# 146735        10025552         Southfield      US   Order Processing Group
# 55309         10023023  Thief River Falls      US  600 South Brooks Avenue
# 80853         10025571         Des Moines      US              PO Box 3283
# 269281        10025039             Mentor      US         9049 Tyler Blvd.
# 262123        10020915            McHenry      US      2600 West Route 120
# 173950        10016858          Beaverton      US  6590 SW Fallbrook Place
# 20901         10019678         Sacramento      US    3248 Auburn Boulevard
# 221388        10026299             Dallas      US    334 North Hall Street
# 39454         10021175       Johnson City      US              PO Box 5418
# 191548        10023715         Plainfield      US         Central Division
#
#                               Customer Address 2  \
# 146735               25140 Lahser Road Suite 282
# 55309
# 80853
# 269281
# 262123
# ...

# %%
fig, axes= plt.subplots(figsize=(15,5))
sns.barplot(x='Sales Margin Amount', y= 'state_name', data=q, palette='coolwarm')
axes.set_title("States where the company gets maximum Sales Margin Amount ")
plt.tight_layout()

# %% [markdown]
# ##Top 10 States where sales had Maximum sales margin amount

# %% [markdown]
# # Insight 3

# %%
add=pd.merge(d_customers,d_salesdetails, on ='Address Number')
p= add[add['Sales Margin Amount'].notna()]
p
# Out:
#         Address Number Business Family  Business Unit           Customer  \
# 9             10025778              R3              1  Valicert Midstore
# 10            10025778              R3              1  Valicert Midstore
# 11            10025778              R3              1  Valicert Midstore
# 12            10025778              R3              1  Valicert Midstore
# 13            10025778              R3              1  Valicert Midstore
# ...                ...             ...            ...                ...
# 298156        10006983              O1              1    Brentano's Shop
# 298157        10006983              O1              1    Brentano's Shop
# 298158        10006983              O1              1    Brentano's Shop
# 298159        10006983              O1              1    Brentano's Shop
# 298160        10006983              O1              1    Brentano's Shop
#
#         Customer Number Customer Type  Division Line of Business  \
# ...

# %%
q = p.loc[p.groupby('Customer')['Sales Margin Amount'].idxmax()].sort_values(by='Sales Margin Amount', ascending=False).head(10)
q
# Out:
#        Address Number Business Family  Business Unit            Customer  \
# 83824        10006919              R3              1   Hoovey SuperStore
# 91127        10025052              O2              1     Target Gigstore
# 60447        10025737              R3              1  Userland Maxistore
# 87123        10007536              R2              1  Calypso Maxi Store
# 48279        10025552              R3              1    Unison Medistore
# 92723        10025241              R1              1           TeamStore
# 57892        10023023              R1              1     Crew Superstore
# 87037        10025353              R2              1         Total Store
# 48102        10025571              R3              1    Unitec Maxistore
# 58198        10025039              R1              1    Tandy Superstore
#
#        Customer Number Customer Type  Division Line of Business         Phone  \
# 83824         10006919            G1         1               M1  816-455-8733
# ...

# %%
fig, axes= plt.subplots(figsize=(15,5))
sns.barplot(x='Sales Margin Amount', y= 'Customer', data=q, palette='coolwarm')
axes.set_title("Customers where the company gets maximum Sales Margin Amount ")
plt.tight_layout()

# %% [markdown]
# ##Top 10 Customers with Maximum Sales Margin amount
